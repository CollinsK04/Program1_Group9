# %%
#void insertion sort(lst)
def insertion_sort(arr):
    N = len(arr)
    for i in range(1, N):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

#void selection sort(lst)
def selection_sort(array):
    size = len(array)
    for ind in range(size):
        min_index = ind

        for j in range(ind + 1, size):
            if array[j] < array[min_index]:
                min_index = j
        (array[ind], array[min_index]) = (array[min_index], array[ind])
    return array

# %%
#Testing
lst = [5,2,4,7,9]
print(insertion_sort(lst))
print(selection_sort(lst))

lst2 = [6,8,9,3,23,2,4545,34,43]
print(insertion_sort(lst2))
print(selection_sort(lst2))
# Out:
# [2, 4, 5, 7, 9]
# [2, 4, 5, 7, 9]

# %%
import time
def benchmark(algorithm, lst):
    arr = list(lst)
    t0 = time.perf_counter()
    out = algorithm(arr)
    if out is not None: _ = out
    return time.perf_counter() - t0

# %%
#Bechnmark
print(benchmark(insertion_sort, lst))
print(benchmark(selection_sort, lst))

print(benchmark(insertion_sort, lst2))
print(benchmark(selection_sort, lst2))
# Out:
# 6.199930794537067e-06
# 6.600050255656242e-06
# 4.400033503770828e-06
# 1.309998333454132e-05
